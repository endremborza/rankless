# %%
from ccl_science_data.common import GenReader, EntC
# Out:
# loading  /home/borza/rankless/.env
# OA_ROOT:  /home/borza/rankless-data
# SNAP_ROOT:  /mnt/hdd/shared/openalex-snapshot-2025-10

# %%
gr = GenReader('..')

# %%
names = sorted(gr.get_names(EntC.AUTHORS), key=len)

# %%
names[-30:]
# Out:
# ['for the Alzheimer’s Disease Neuroimaging Initiative',
#  'Heloísa Cristina Quatrini Carvalho Passos Guimarães',
#  'José Baltazar Salgueirinho Osório de Andrade Guerra',
#  'Centro Internacional de Mejoramiento de Maíz y Trigo',
#  'on behalf of the PolExPIR and PolExNIB Investigators',
#  'for the Mexican Nephrology Collaborative Study Group',
#  'no-firstname EFSA Panel on Animal Health and Welfare',
#  'Claudia Christina Ribeiro Guimarães Neri de Magalhães',
#  'for the RED-CABG Steering Committee and Investigators',
#  'Centro Internacional de Mejoramiento de Maíz y Trigo .',
#  'Wisurumuni Arachchilage Hasitha Maduranga Karunarathne',
#  'Sri Lanka. Janalēkhana hā Saṅkhyālēkhana Depārtamēntuva',
#  'Hong Kong Institute for Monetary and Financial Research',
#  'Food and Agriculture Organization of the United Nations',
#  'Hong Kong Institute for Monetary and Financial Research',
#  'Nordic Council of Ministers Nordic Council of Ministers',
# ...

# %%
sorted(gr.get_names(EntC.INSTITUTIONS), key=len)[-10:]
# Out:
# ["École Nationale Supérieure d'Électrotechnique, d'Électronique, d'Informatique, d'Hydraulique et des Télécommunications",
#  'Centro Tecnológico de Investigación, Desarrollo e Innovación en tecnologías de la Información y las Comunicaciones (TIC)',
#  '"National Medical Research Center for Rehabilitation and Balneology" of the Ministry of Health of the Russian Federation',
#  'All-Russian State Scientific Research Institute for Control, Standardization and Certification of Veterinary Preparations',
#  'The National Institute of Research – Development for Machines and Installations Designed for Agriculture and Food Industry',
#  'Federal State Budgetary Institution "Federal Center For Cardiovascular Surgery" Ministry of Health of The Russian Federation',
#  'The Ohio State University Comprehensive Cancer Center – Arthur G. James Cancer Hospital and Richard J. Solove Research Institute',
# ...

# %%
len(sorted(gr.get_names(EntC.INSTITUTIONS), key=len)[-10])
# Out:
# 118
